# %% [markdown]
# # Intersection of Two Linked Lists
#
# ### Problem Statement
# Given the heads of two linked lists, return the node at which the two lists intersect
#
# ![linkedListIntersection.png](attachment:linkedListIntersection.png)
#
# [Leetcode Problem Link](https://leetcode.com/problems/intersection-of-two-linked-lists/)

# %% [markdown]
# ## Hash Table Approach
#
# A very intuitive way to approach this problem is to iterate over A once, then store all the traversed nodes into a hash table or set. Then while iterating over B, check if the node is in the hash table. If
#
# ### Analysis
# * Time Complexity: O(M+N) given len(A) = M, len(B) = N
#     * we need to iterate over A once
#     * we'll also need to iterate over at least part of B, and all of B in the worst case
# * Space Complexity: O(M)
#     * we need to store all the nodes of A in the hash table
#     * not the most space efficient solution

# %%
class Node:
    def __init__(self, x):
        self.val = x
        self.next = None

def findIntersection()
